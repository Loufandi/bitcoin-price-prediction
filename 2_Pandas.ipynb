# %% [markdown]
# I. INTRODUCTION:
#
#
# The importance of learning these skills about machine learning and python :
#
# * Scikit-learn to handle basic ML algorithms such as clustering, logistic and linear regression, regression, and classification.
#
# * Pandas are used for advanced structure and data analysis. It allows you to merge and filter data and collect data from other external sources (such as Excel).
#
# * Keras is used for deep learning. In addition to the computer’s CPU, it also uses the GPU, allowing rapid calculations and prototyping.
#
# * TensorFlow is used to manipulate deep understanding by building, training, and using artificial neural networks using substantial data sets.
#
#
# In this tutorial we will focus on Pandas and it's different uses and functions.
#
#
# Pandas is one of the tools in Machine Learning which is used for data cleaning and analysis. It has features which are used for exploring, cleaning, transforming and visualizing from data.

# %% [markdown]
# II. Pandas:
#
# Like all other packages and libraries, first step is always to import necessary packages into your workplace.
#
#
# If you are using your local IDE (You can know more about Pyton IDEs that you can use, please links in the references section.
#
#
# If you are using googlecolab you can directly import pandas.
#
#
#
#
# 1. Import pandas

# %%
import pandas as pd

# %% [markdown]
# By using the above command you can easily import pandas library.
#
#
# Before getting into more details it is necessary to have some notions about data sturctures used in Pandas
#
#
# 2. Pandas Data Structures
#
#
# Pandas deals with three types of data structures :
#
# 2.1. Series
#
#
# 2.2. DataFrame
#
#
# 2.3. Panel
#
#
# We will go through everytype of them:
#
#
# 2.1. Series is a one-dimensional array-like structure with homogeneous data.  homogeneous data, simply it means that it only can store one type of data. PLease check the references for more infos.
#
# It is also worth mentionning that the size of the series is immutable(cannot be changed) but its values are mutable.
#
# ![image.png](data:image/png;base64,...)
#
# 2.2. DataFrame is a two-dimensional array-like structure with heterogeneous data.
#
#
# Data is aligned in a tabular manner(Rows &Columns form). The size and values of DataFrame are mutable.
#
# ![image.png](data:image/png;base64,...)
#
# 2.3. The panel is a three-dimensional data structure with heterogeneous data.
#
#
# It is hard to represent the panel in graphical representation. But it can be illustrated as a container of DataFrame. The size and values of a Panel are mutable.
#
# ![image.png](data:image/png;base64,...)
#
#
# Note: Series and DataFrame are the most widely used data structure in pandas. Therefore, we will only discuss these two data structures later.
#
#
# 2.1.1. Creating Series and Data Frames
#
#
# ** Series :
#
# pandas.Series(data=None , index=None , dtype=None,copy = false)
#
# **parameters:
#
# * data: data takes various forms like ndarray, list, constants
#
# * index: index values must be unique and hashable, the same length as data. Default np.arrange(n) if no index is passed.
#
# * dtype: dtype is for data type. If None, the data type will be inferred
#
# * copy: Copy input data. default false

# %%
import numpy as np #Numpy here is necessary as we declaring an array !
data = np.array(['a','b','c','d'])
#Creating a Series of the array previosuly created
example_1 = pd.Series(data,index=(0,1,2,3))
print (example_1)
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %% [markdown]
# 2.1.2. Creating Series from Dictionary

# %%
#Transforming heterogenous data into series:
data = {'a' : 0., 'b' : 1., 'c' : 2.}
s = pd.Series(data)
print (s)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %% [markdown]
# 2.1.3. Creating Series from scalar

# %%
#Using ONE value of a scalar :
s = pd.Series(5, index=[0, 1, 2, 3])
print (s)
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# dtype: int64

# %%
#EXERCISE:
#Create a pandas series from each of the items below: a list, numpy and a dictionary
"""
a_list = list("abcdefg")
numpy_array = np.arange(1, 10)
dictionary = {"A":  0, "B":1, "C":2, "D":3, "E":5}

NOTE: You will need to import numpy
"""

# %% [markdown]
# 2.2. Dataframe:
#
#
# pandas.DataFrame(data=None , index=None , dtype=None,copy = false)
#
# parameters:
#
# * data: data takes various forms like ndarray, list, constants
#
# * index-: index values must be unique and hashable, the same length as data. Default np.arrange(n) if no index is passed.
#
# * dtype: dtype is for data type. If None, the data type will be inferred
#
# * copy: Copy input data. default false
#
# 2.2.1. Creating DataFrame from List

# %%
#example1
data = [1,2,3,4,5]
#Transforming an array to a dataframe:
df = pd.DataFrame(data)
print (df)
#example2
data = [['Alex',10],['Bob',12],['Clarke',13]]
#Transforming "data" to a dataframe(Not like series only for homogenous data)
df = pd.DataFrame(data,columns=['Name','Age'],dtype=float)
print (df)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5
#      Name   Age
# 0    Alex  10.0
# 1     Bob  12.0
# 2  Clarke  13.0
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: Could not cast to float64, falling back to object. This behavior is deprecated. In a future version, when a dtype is passed to 'DataFrame', either all columns will be cast to that dtype, or a TypeError will be raised
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# 2.2.2. Create a DataFrame from Dict of ndarrays / Lists
#
#
#
# All the ndarrays must be of the same length. If the index is passed, then the length of the index should equal to the length of the arrays.
#
#
# If no index is passed, then by default, the index will be a range(n), where n is the array length.

# %%
#Creating a dictionnary:
data ={'Name':['Tom', 'Jack', 'Steve', 'Ricky'],'Age':[28,34,29,42]}
#Transforming it to dataframe
df = pd.DataFrame(data)
print (df)
# Out:
#     Name  Age
# 0    Tom   28
# 1   Jack   34
# 2  Steve   29
# 3  Ricky   42

# %% [markdown]
# 3. Pandas: How to read and write files?
#
#
# Pandas can read and write any types of files such as Excel, CSV and many other files, it is one of its crucial features. Methods like df.read_*() and df.to_*() helps you to work with all types of files effectively.
#
# We will use Iris-dataset for the explanation (link in the references).

# %%
#sklearn is "must have tool" for any application that contains datasets and ML models
from sklearn import datasets
#uploading the dataset
data= datasets.load_iris()
#shaping the dataset using the dataframe fuction (refer to figure below)
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# Similarly, you can read and write other files also.
#
# ![image.png](data:image/png;base64,...)
#
# 3.1. DataFrame columns and rows(.shape) & Number of dimensions.
#
#
# 3.1.1. df.shape function in pandas returns the output as (m,n) where m is a number of rows and n is the number of columns in the data frame.
#
#
# 3.1.2. df.ndim return an int representing the number of axes/array dimensions. It will return 1 for Series and 2 for DataFrame.
#
# 3.2. Preview DataFrame with .head()& .tail()
#
# 3.2.1. df.head(n=no. of rows to be returned) returns the first n rows from the DataFrame.
#
# 3.2.1. df.tail(n=no. of rows to be returned) returns the last n rows from the DataFrame.
#
#
# 4. High-level statistics with pandas
#
#
# 4.1. Pandas DataFrame.describe()
#
# The describe() method is used for calculating some statistical data like percentile, mean and std of the numerical values of the Series or DataFrame. It analyzes both numeric and object series and also the DataFrame column sets of mixed data types.

# %%
#"df" being the dataset we uploaded
#"describe" function give statistical insights on the dataset
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %% [markdown]
# 5. dtypes and .astype() functions in Pandas
#
# To check the data types of columns of the data frame .dtypes function is used. Series have only one type of data types but in a data frame, there can be mixed data types.

# %%
df.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                 int64
# dtype: object

# %% [markdown]
# Note: Any column in the data frame having character/string appear as ‘object’ datatypes.
#
# If you want to change the data type of a specific column in the data frame, use the .astype() function.
#
# For example, to see the ‘SepalLengthCm’ column as a string

# %%
df['sepal length (cm)'].astype(str)
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length (cm), Length: 150, dtype: object

# %% [markdown]
# 6. Selection of columns and rows in Pandas DataFrame
#
#
# Three primary methods for selecting columns from data frames in pandas.
#
#
# 6.1. df.column_name (Dot notation)

# %%
df['target']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %% [markdown]
# 6.2. Selecting rows:
#
# Rows in a DataFrame are selected, typically, using the iloc/loc selection methods, or using logical selectors (selecting based on the value of another column or variable).

# %%
#SEelectign raws from 0 to 5th raw , all columns :
df.iloc[0:5,].head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# 6.3. Selecting both rows and columns at a time

# %%
#SElecting raws from the 1 to the 5th raw and keeping only second column:
df.iloc[0:5,1].head()
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# Name: sepal width (cm), dtype: float64

# %% [markdown]
# 7. Filtering

# %%
#Keeping only values of teh column : "sepal length" that have value more than 6.3
df[df['sepal length (cm)']>6.3].head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 54                6.5               2.8                4.6               1.5
# 58                6.6               2.9                4.6               1.3
#
#     target
# 50       1
# 51       1
# 52       1
# 54       1
# 58       1

# %% [markdown]
# 8. Manipulating DataFrames in Pandas
#
# 8.1. Renaming Columns in a data frame
#
# Column renames can be achieved easily in Pandas using the DataFrame rename( ) function.
#
# df.rename(columns = {“old_column_name”: “new_column_name”})

# %%
df.rename(columns={'sepal length (cm)':'Sepal_Length'})
# Out:
#      Sepal_Length  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0             5.1               3.5                1.4               0.2
# 1             4.9               3.0                1.4               0.2
# 2             4.7               3.2                1.3               0.2
# 3             4.6               3.1                1.5               0.2
# 4             5.0               3.6                1.4               0.2
# ..            ...               ...                ...               ...
# 145           6.7               3.0                5.2               2.3
# 146           6.3               2.5                5.0               1.9
# 147           6.5               3.0                5.2               2.0
# 148           6.2               3.4                5.4               2.3
# 149           5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %% [markdown]
# 8.2. Deleting rows and columns in a data frame
#
# Pandas use the “drop( )” function to delete rows and columns from DataFrames
#
# df.drop(name _or _names ,axis= ‘columns’/1 OR ‘rows’ /0)
#
# 8.2.1. Deleting columns from Data Frame.

# %%
df.drop(["sepal width (cm)"],axis= 1).head()
# Out:
#    sepal length (cm)  petal length (cm)  petal width (cm)  target
# 0                5.1                1.4               0.2       0
# 1                4.9                1.4               0.2       0
# 2                4.7                1.3               0.2       0
# 3                4.6                1.5               0.2       0
# 4                5.0                1.4               0.2       0

# %% [markdown]
# 9. Dealing with Missing Values
#
# Many datasets have missing values, pandas provide multiple ways to deal with it.
#
# 9.1. Finding missing values
#
# To detect any missing values in a data frame, provide functions like isnull(), isna(). Both of them do the same thing.

# %%
df.isna().head(3)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0              False             False              False             False
# 1              False             False              False             False
# 2              False             False              False             False
#
#    target
# 0   False
# 1   False
# 2   False

# %% [markdown]
# Note: You can also choose to use notna() which is just the opposite of isna().
#
# Using df.isna().sum() you can get the number of missing values in each column.

# %%
df.isna().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# target               0
# dtype: int64

# %% [markdown]
# 9.2. Drop missing values.
#
# To drop a row or column with missing values, pandas provide dropna() function.
#
# df.dropna(axis=0 or 1,how = ‘any’ or ‘all’)
#
# ‘any’: drop if there is any missing value
# ‘all’: drop if all values are missing
# iii)Replacing missing values
#
# To replace any missing value from the data frame, pandas provide fillna() function.
#
# 10. Computation with pandas DataFrame
#
#
# 10.1. Element-By-Element Mathematical Operations in DataFrame
#
# Many operations such as addition, subtraction, multiplication, division e.t.c can be done elementwise in any data frame by the following ways:
#
# df+ λ (addition where λ is any scalar value)
#
# Similarly, df — λ is for subtraction & df*λ is for multiplication

# %%
df["sepal length (cm)"] + 1
# Out:
# 0      6.1
# 1      5.9
# 2      5.7
# 3      5.6
# 4      6.0
#       ...
# 145    7.7
# 146    7.3
# 147    7.5
# 148    7.2
# 149    6.9
# Name: sepal length (cm), Length: 150, dtype: float64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 10.2.  Statistical operations in DataFrame
#
# 10.2.1 count( ) : Number of non-null observations

# %%
df["sepal length (cm)"].count()
# Out:
# 150

# %% [markdown]
# 10.2.2. sum( ): Sum of values

# %%
df["sepal length (cm)"].sum()
# Out:
# 876.5

# %% [markdown]
# 10.2.3.  mean(): Mean of values

# %%
df["sepal length (cm)"].mean()
# Out:
# 5.843333333333334

# %% [markdown]
# Other important satistical functions in pandas are:-
#
# mad( ): Mean absolute deviation
#
# median( ):Arithmetic median of values
#
# min( ): Minimum
#
# max( ): Maximum
#
# mode( ): Mode
#
# prod( ): Product of values
#
# std( ): Bessel-corrected sample standard deviation
#
# var( ): Unbiased variance
#
# sem( ): Standard error of the mean
#
# skew( ): Sample skewness (3rd moment)
#
# Kurt( ): Sample kurtosis (4th moment)
#
# quantile( ): Sample quantile (Value at %)
#
# value_counts( ):Count of unique values
#
# corr(): example: data = pd.DataFrame(df)
#
#   print(data.corr())

# %%
#EXERCISE:
#from sklearn import the dataset : boston houses prices (from sklearn.datasets import load_boston)
#Define the loaded dataset as a Dataframe
#Display the 10 first lines of this dataframe
#Give a statistical description of the dataset
#Display the different datatypes in the loaded dataset
#Check if there are any null values in the dataset
#Calculate and display the correlation of the features in the dataset
#Calculate and display the shape of the dataset
#Knowing the "price" is the target variable (a target variable is simply the variables that we are predicting or calssifiying or clustering depends on the task)
"""
Set the features(X) and target (Y) using the "iloc" function
"""

# %% [markdown]
# References:
#
#
# [1] https://pandas.pydata.org/docs/
#
# [2] https://pandas.pydata.org/docs/user_guide/index.html
#
#
# [3] https://pandas.pydata.org/getting_started.html
#
#
# [4] https://pandas.pydata.org/docs/development/index.html#development
#
#
# [5] https://scikit-learn.org/stable/auto_examples/datasets/plot_iris_dataset.html
#
#
# [6] https://pypi.org/project/pandas/
#
#
# [7] https://github.com/pandas-dev/pandas
